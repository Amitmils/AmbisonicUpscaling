# %%
from sound_field import SoundField,divide_to_subbands,divide_to_time_windows,create_grid
from signal_info import signal_info
from optimizer import optimizer
from optimizer_v2 import optimizer_v2
from DoA_est import DoA_via_bands
import utils
import numpy as np
import math
import time
import torch
from typing import List,Union
import os
from collections import defaultdict,Counter
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import multiprocessing as mp
import inspect
import pandas as pd



LEBEDEV = 'lebedev'
POINTS_162 = '162_points'

# %%
dataset_path = r"data\WSJ0"
input_order = 1
upscale_order = 3

# %%
def generate_random_doas(num_speakers : int ,min_theta : float = 0,max_theta : float = 90,min_phi : float = -180,max_phi : float= 180,min_dist : float = 15):
    doas = list()
    while len(doas) < num_speakers:
        random_doa = np.array([random.uniform(min_theta,max_theta),random.uniform(min_phi,max_phi)])
        if any([np.sqrt(np.sum((random_doa - doa)**2)) < min_dist for doa in doas]):
            continue
        doas.append(random_doa)
    return doas

# %%
def create_sound_field_wrapper(speaker_wavs,config,local_id,max_seconds):
    doas = generate_random_doas(
            len(speaker_wavs),
            min_theta=config['min_theta'],
            max_theta=config['max_theta'],
            min_phi=config['min_phi'],
            max_phi=config['max_phi'],
            min_dist=config['min_dist'],
        )
    signals = [
        signal_info(
            signal_path=speaker_wavs[i],
            th=doa[0],
            ph=doa[1],
        )
        for i, doa in enumerate(doas)
    ]
    sound_field = SoundField(maximum_seconds=max_seconds)

    anm_f,gt_anm_f_upscaled= sound_field.create(
        signals=signals,
        input_order=input_order,
        output_order=upscale_order,
        SH_type='complex',
        debug=False,
        n_fft=config['n_fft'],
        grid_type=config['grid_type'],
    )
    global_id =  config['base_id'] + local_id
    meta_data = {'ID' : global_id,'type' : config['type'], "num_speakers" : len(doas),'DOAs':[(round(theta.item(),2),round(phi.item(),2)) for theta,phi in doas],'file_paths':speaker_wavs,'sr' : sound_field.sr.item()}

    return (global_id,anm_f,gt_anm_f_upscaled),meta_data

# %%
def create_dataset(
    wav_files_path: List[str],
    type : str,
    base_id : int = 0,
    input_order: int = 1,
    upscaled_order: int = 3,
    num_bins : int = 45,
    window_length : int = 1024,
    max_num_windows : int = 10,
    min_num_speakers: int = 1,
    max_num_speakers: int = 4,
    min_theta: float = 0,
    max_theta: float = 90,
    min_phi: float = -180,
    max_phi: float = 180,
    min_dist: float = 15,
    sr : int = 16000,
    n_fft :int = 256,
    max_seconds : int = 5,
    grid_type : str = POINTS_162,
):
    # Get all input arguments as a dictionary
    frame = inspect.currentframe()
    args, _, _, values = inspect.getargvalues(frame)
    config_dict = {arg: values[arg] for arg in args if arg != 'wav_files_path'}

    total_num_wav_files = len(wav_files_path)
    num_wav_files_used = 0
    speaker_groups = list()
    
    while num_wav_files_used < total_num_wav_files:
        num_speakers = min(
            random.randint(min_num_speakers, max_num_speakers), total_num_wav_files - num_wav_files_used
        )
        speaker_groups.append(wav_files_path[num_wav_files_used:num_wav_files_used+num_speakers])
        num_wav_files_used += num_speakers

    data_set = list()
    meta_data = list()

    for group_num,group in enumerate(tqdm(speaker_groups)):
        try:
            data,config = create_sound_field_wrapper(group,config_dict,group_num,max_seconds)
            data_set.append(data)
            meta_data.append(config)
        except Exception as e:
            print(f"Error occured while processing group {group} : {e}")

    
    # with mp.Pool(processes=mp.cpu_count()) as pool:
    #     with tqdm(total=len(speaker_groups)) as pbar:
    #         for result in pool.imap(create_sound_field_wrapper, [(2,1) for group in speaker_groups]):
    #             data_set.append(result)
    #             pbar.update()  # Update the progress bar for each completed task
    return data_set,meta_data

# %%
def get_wav_files_in_folder(path,shuffle=True):
    wav_files = list()
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(".wav"):
                wav_files.append(os.path.join(root, file))
    if shuffle:
        random.shuffle(wav_files)
    return wav_files

# %%
dataset_name = os.path.basename(dataset_path)
dataset = dict()
base_id = 0
dataset_metadata = dict()
OUTPUT_FOLDER = r"data\ModelDataSets\WSJ_4_3_25"
MAX_SECONDS = 2
os.makedirs(OUTPUT_FOLDER, exist_ok=True)  # Create directory if not exists
for folder in os.listdir(dataset_path):
    if not(os.path.isdir(os.path.join(dataset_path,folder))):
        continue
    dataset[folder] = dict()
    wav_files = get_wav_files_in_folder(os.path.join(dataset_path,folder))
    print(f"Creating {folder} dataset for {dataset_name}")

    dataset[folder],dataset_metadata[folder] = create_dataset(wav_files,type = folder,base_id=base_id,max_seconds=MAX_SECONDS)
    base_id += len(dataset[folder])
    print(f"Complete - Size : {len(dataset[folder])}")

df = pd.DataFrame([item for folder_data in dataset_metadata.values() for item in folder_data]).set_index('ID')
df.to_csv(os.path.join(OUTPUT_FOLDER,'metadata.csv'))
# Out:
# Creating test dataset for WSJ0
# 100%|██████████| 22/22 [00:00<00:00, 62.60it/s]
# Complete - Size : 22
# Creating train dataset for WSJ0
# 100%|██████████| 2275/2275 [00:28<00:00, 80.66it/s]
# Complete - Size : 2275
# Creating validation dataset for WSJ0
# 100%|██████████| 152/152 [00:01<00:00, 79.62it/s]
# Complete - Size : 152

# %%
import torch
import os
import zipfile
import io

def save_large_dataset_compressed(dataset, folder_path, zip_filename="dataset_compressed.zip"):

    for split_name, split_data in dataset.items():  # test, validation, train
        # Create a zip file for each split
        zip_filename = f"{split_name}.zip"
        zip_file_path = os.path.join(folder_path, zip_filename)

        # Open the zip file in write mode with no compression (using ZIP_STORED)
        with zipfile.ZipFile(zip_file_path, 'w', compression=zipfile.ZIP_STORED) as zipf:
            for idx, tensor1, tensor2 in tqdm(split_data, total=len(split_data), desc=split_name):
                file_name = f"{split_name}_{idx}.pth"
                buffer = io.BytesIO()  # Buffer to hold the tensor data
                torch.save((idx, tensor1, tensor2), buffer)  # Save to buffer
                zipf.writestr(file_name, buffer.getvalue())  # Write to zip file

# Example: Save the dataset compressed
save_large_dataset_compressed(dataset, OUTPUT_FOLDER)
# Out:
# ...
# validation: 100%|██████████| 152/152 [00:00<00:00, 156.70it/s]

# %%
data = torch.load(r'data\WSJ0\Dataset_testv2.pt')
# Out:
# C:\Users\amitmils\AppData\Local\Temp\ipykernel_17628\3121382940.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(r'data\WSJ0\Dataset_testv2.pt')

# %%
with zipfile.ZipFile(r'data\ModelDataSets\WSJ_4_3_25\train\WSJ_train.zip', 'r') as zipf:
        print(zipf.namelist())
# Out:
# ['train_27.pth', 'train_28.pth', 'train_29.pth', 'train_30.pth', 'train_31.pth', 'train_32.pth', 'train_33.pth', 'train_34.pth', 'train_35.pth', 'train_36.pth', 'train_37.pth', 'train_38.pth', 'train_39.pth', 'train_40.pth', 'train_41.pth', 'train_42.pth', 'train_43.pth', 'train_44.pth', 'train_45.pth', 'train_46.pth', 'train_47.pth', 'train_48.pth', 'train_49.pth', 'train_50.pth', 'train_51.pth', 'train_52.pth', 'train_53.pth', 'train_54.pth', 'train_55.pth', 'train_56.pth', 'train_57.pth', 'train_58.pth', 'train_59.pth', 'train_60.pth', 'train_61.pth', 'train_62.pth', 'train_63.pth', 'train_64.pth', 'train_65.pth', 'train_66.pth', 'train_67.pth', 'train_68.pth', 'train_69.pth', 'train_70.pth', 'train_71.pth', 'train_72.pth', 'train_73.pth', 'train_74.pth', 'train_75.pth', 'train_76.pth', 'train_77.pth', 'train_78.pth', 'train_79.pth', 'train_80.pth', 'train_81.pth', 'train_82.pth', 'train_83.pth', 'train_84.pth', 'train_85.pth', 'train_86.pth', 'train_87.pth', 'train_88.pth', 'trai
# ...

# %%
import zipfile
import torch
import io
from torch.utils.data import Dataset, DataLoader

class LazyLoadDataset(Dataset):
    def __init__(self, zip_filename, split_name="train"):
        self.zip_filename = zip_filename
        self.split_name = split_name

    def __len__(self):
        # Return the number of samples stored in the zip file (you can track the total number of samples)
        with zipfile.ZipFile(self.zip_filename, 'r') as zipf:
            return len([name for name in zipf.namelist() if name.startswith(self.split_name)])

    def __getitem__(self, idx):
        # Lazy load each sample from the zip file
        with zipfile.ZipFile(self.zip_filename, 'r') as zipf:
            with zipf.open(f"{self.split_name}_{idx}.pth") as f:
                label, tensor1, tensor2 = torch.load(f)  # Load sample lazily
        return label, tensor1, tensor2

# Example: Using the LazyLoadDataset
dataset = LazyLoadDataset("dataset_compressed.zip", split_name="train")
train_loader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=4)

# Training loop
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for batch in train_loader:
    labels, tensor1, tensor2 = [x.to(device, non_blocking=True) for x in batch]
    # Your model processing code
    # ...
